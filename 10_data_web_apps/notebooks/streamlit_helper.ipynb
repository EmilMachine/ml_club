# %%
import streamlit as st

# %%
st.line_chart?

# %%
dir(st)
# Out:
# ['List',
#  'RootContainer',
#  'StopException',
#  'StreamlitAPIException',
#  '_DeltaGenerator',
#  '_ForwardMsg_pb2',
#  '_LOGGER',
#  '_RerunData',
#  '_RerunException',
#  '_SPACES_RE',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_add_report_ctx',
#  '_beta_warning',
#  '_code_util',
#  '_config',
#  '_contextlib',
#  '_env_util',
#  '_get_report_ctx',
#  '_is_running_with_streamlit',
#  '_logger',
#  '_main',
#  '_maybe_print_repl_warning',
#  '_parse',
#  '_pkg_resources',
#  '_re',
#  '_repl_warning_has_been_displayed',
#  '_source_util',
#  '_string_util',
#  '_sys',
#  '_textwrap',
#  '_threading',
#  '_traceback',
#  '_transparent_write',
#  '_update_logger',
#  'altair_chart',
#  'area_chart',
#  'audio',
#  'balloons',
#  'bar_chart',
#  'beta_color_picker',
#  'beta_columns',
#  'beta_container',
#  'beta_expander',
#  'beta_set_page_config',
# ...

# %%
st.pyplot?
